# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
# Import API key
from api_keys import geoapify_key
import requests
from requests.structures import CaseInsensitiveDict
import folium
from folium import plugins
import json


# url = "https://api.geoapify.com/v1/geocode/search?text=38%20Upper%20Montagu%20Street%2C%20Westminster%20W1H%201LJ%2C%20United%20Kingdom&apiKey=" + geoapify_key

# headers = CaseInsensitiveDict()
# headers["Accept"] = "application/json"

# resp = requests.get(url, headers=headers)

# print(resp.status_code)

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
coords = []
indx = 0

city_data_df
# Out:
#      City_ID           City      Lat       Lng  Max Temp  Humidity  \
# 0          0          airai  -8.9266  125.4092     18.52        89
# 1          1  cockburn town  21.4612  -71.1419     25.27        80
# 2          2     hambantota   6.1241   81.1185     32.19        66
# 3          3        rikitea -23.1203 -134.9692     26.55        77
# 4          4        mataura -46.1927  168.8643      8.16        73
# ..       ...            ...      ...       ...       ...       ...
# 560      560  maarianhamina  60.0973   19.9348     -0.66       100
# 561      561          nador  35.1740   -2.9287     13.14        82
# 562      562      dalianwan  39.0286  121.6950     12.02        58
# 563      563        veraval  20.9000   70.3667     27.44        56
# 564      564         tabriz  38.0800   46.2919      8.70        66
#
#      Cloudiness  Wind Speed Country        Date
# 0           100        1.10      TL  1679380430
# 1             2        3.57      TC  1679380405
# 2            40        2.57      LK  1679380431
# 3            93        6.16      PF  1679380432
# 4            97        2.31      NZ  1679380432
# ..          ...         ...     ...         ...
# 560         100        2.06      AX  1679380784
# 561          20        2.06      MA  1679380785
# 562           8        6.00      CN  1679380786
# 563          48        4.55      IN  1679380786
# 564          75        5.14      IR  1679380224
#
# [565 rows x 10 columns]

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display
# Configure the map plot

""" 
I could not install the library geoViews, I broke my anaconda environment trying to install this library in an unconventional way by manually downloading dependencies
see below and also downloading the library and installing locally without luck, so I gave folium a try. 

Nothing worked for geoViews. Spent too much time trying to make it work unsuccessfully.
Tried with python 3.7.9, 3.9.13 in a clean installatioin in my OS and in the anaconda environments.  

So instead of adding the humidity as the size of the marker, I added a tooltip with that shows the humidity, please see the HTML file and click on the cities to see it working. 
Other than that I feel I completed all that was requested in the challenge. Thank you! 

Cartopy-0.20.2-cp39-cp39-win_amd64.whl
Shapely-1.8.2-cp39-cp39-win_amd64.whl
geoviews-1.9.6-py2.py3-none-any.whl

"""
# YOUR CODE HERE
m = folium.Map()
for i in range (0, len(city_data_df)):
    folium.Marker([city_data_df.iloc[i]['Lat'], \
                city_data_df.iloc[i]['Lng']], popup=city_data_df.iloc[i]['City'], \
                tooltip="HUMIDITY - " + str(city_data_df.iloc[i]['Humidity']) ).add_to(m)
# Display the map
# YOUR CODE HERE
m.save("output_data/map.html")
print("To interact with the MAP go to output_data/map.html" )
m
# Out:
# To interact with the MAP go to output_data/map.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc1b47494d1451502e6aaa898a782043 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc1b47494d1451502e6aaa898a782043&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc1b47494d1451502e6aaa898a782043 = L.map(
#                 &quot;map_dc1b47494d1451502e6aaa898a782043&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d19a1fa8e54b0877bba0c7a430c8b95 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dc1b47494d1451502e6aaa898a782043);
#
#
#             var marker_e148d9d3d632f0ab267e8f40c3ed465b = L.marker(
#                 [-8.9266, 125.4092],
#                 {}
#             ).addTo(map_dc1b47494d1451502e6aaa898a782043);
#
#
#         var popup_234dc9800543ce8cfd0366eb1f466d14 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b60453df9de57f8e1550e07ccf1ace62 = $(`&lt;div id=&quot;html_b60453df9de57f8e1550e07ccf1ace62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;airai&lt;/div&gt;`)[0];
#                 popup_234dc9800543ce8cfd0366eb1f466d14.setContent(html_b60453df9de57f8e1550e07ccf1ace62);
#
#
#
#         marker_e148d9d3d632f0ab267e8f40c3ed465b.bindPopup(popup_234dc9800543ce8cfd0366eb1f466d14)
#         ;
#
#
#
#
#             marker_e148d9d3d632f0ab267e8f40c3ed465b.bindTooltip(
#                 `&lt;div&gt;
#                      HUMIDITY - 89
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7269991f13dff3e65dd500a0975eafb1 = L.marker(
#                 [21.4612, -71.1419],
#                 {}
#             ).addTo(map_dc1b47494d1451502e6aaa898a782043);
#
#
#         var popup_616e898e56d0592dfec57962b6944358 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_638b6606cbf330a688a867ed07b45810 = $(`&lt;div id=&quot;html_638b6606cbf330a688a867ed07b45810&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;cockburn town&lt;/div&gt;`)[0];
#                 popup_616e898e56d0592dfec57962b6944358.setContent(html_638b6606cbf330a688a867ed07b45810);
#
#
#
#         marker_7269991f13dff3e65dd500a0975eafb1.bindPopup(popup_616e898e56d0592dfec57962b6944358)
#         ;
#
#
#
#
#             marker_7269991f13dff3e65dd500a0975eafb1.bindTooltip(
#                 `&lt;div&gt;
#                      HUMIDITY - 80
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_65aca0262a3e460a11e24f97df9a3faa = L.marker(
#                 [6.1241, 81.1185],
#                 {}
#             ).addTo(map_dc1b47494d1451502e6aaa898a782043);
#
#
#         var popup_c365defa49f3603b1639c67437d7f8bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31d20348278a03b8cc89afcd1b0f2a29 = $(`&lt;div id=&quot;html_31d20348278a03b8cc89afcd1b0f2a29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;hambantota&lt;/div&gt;`)[0];
#                 popup_c365defa49f3603b1639c67437d7f8bc.setContent(html_31d20348278a03b8cc89afcd1b0f2a29);
#
#
#
#         marker_65aca0262a3e460a11e24f97df9a3faa.bindPopup(popup_c365defa49f3603b1639c67437d7f8bc)
#         ;
#
#
#
#
#             marker_65aca0262a3e460a11e24f97df9a3faa.bindTooltip(
#                 `&lt;div&gt;
#                      HUMIDITY - 66
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3891d7052b2abfb943b7e639e6f82494 = L.marker(
#                 [-23.1203, -134.9692],
#                 {}
#             ).addTo(map_dc1b47494d1451502e6aaa898a782043);
#
#
#         var popup_ce9716300b6934520d72bff901b5174a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f774c60292a644a4b49f5d3abc1206c = $(`&lt;div id=&quot;html_5f774c60292a644a4b49f5d3abc1206c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;rikitea&lt;/div&gt;`)[0];
#                 popup_ce9716300b6934520d72bff901b5174a.setContent(html_5f774c60292a644a4b49f5d3abc1206c);
#
#
#
#         marker_3891d7052b2abfb943b7e639e6f82494.bindPopup(popup_ce9716300b6934520d72bff901b5174a)
#         ;
#
#
#
#
#             marker_3891d7052b2abfb943b7e639e6f82494.bindTooltip(
#                 `&lt;div&gt;
#                      HUMIDITY - 77
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_df3d700

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE

# Drop any rows with null values
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = # YOUR CODE HERE
params = {
    # YOUR CODE HERE
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    # YOUR CODE HERE
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = # YOUR CODE HERE
    params["bias"] = # YOUR CODE HERE
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = # YOUR CODE HERE
    
    # Convert the API response to JSON format
    name_address = # YOUR CODE HERE
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
#   File "C:\Users\Gus Bustillos\AppData\Local\Temp\ipykernel_17268\788381735.py", line 2
#     radius = # YOUR CODE HERE
#                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE
